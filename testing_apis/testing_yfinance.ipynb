# %%
import yfinance as yf
import json

msft = yf.Ticker("msft")
if msft is None:
    print('Yes')
else:
    print('No')
# Out:
# No

# %%
msft.financials
# Out:
#                                             2021-06-30      2020-06-30  \
# Research Development                     20716000000.0   19269000000.0
# Effect Of Accounting Charges                      None            None
# Income Before Tax                        71102000000.0   53036000000.0
# Minority Interest                                 None            None
# Net Income                               61271000000.0   44281000000.0
# Selling General Administrative           25224000000.0   24523000000.0
# Gross Profit                            115856000000.0   96937000000.0
# Ebit                                     69916000000.0   53145000000.0
# Operating Income                         69916000000.0   53145000000.0
# Other Operating Expenses                          None            None
# Interest Expense                         -2330000000.0   -2591000000.0
# Extraordinary Items                               None            None
# ...

# %%
msft.balance
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 msft.balance
#
# AttributeError: 'Ticker' object has no attribute 'balance'

# %%
# get stock info
msft.info
# Out:
# {'zip': '98052-6399',
#  'sector': 'Technology',
#  'fullTimeEmployees': 181000,
# ...

# %%
msft.info['symbol']

# %%
msft.info['shortName']

# %%
msft.info[['shortName', 'symbol']]

# %%
# get historical market data
hist = msft.history(period="max")
hist = hist[['Open', 'High', 'Low', 'Close']]
hist

# %%
msft.history(period="max")
# Out:
#                   Open        High         Low       Close      Volume  \
# Date
# 1986-03-13    0.055654    0.063838    0.055654    0.061109  1031788800
# 1986-03-14    0.061109    0.064384    0.061109    0.063292   308160000
# 1986-03-17    0.063292    0.064929    0.063292    0.064384   133171200
# 1986-03-18    0.064384    0.064929    0.062201    0.062746    67766400
# 1986-03-19    0.062746    0.063292    0.061109    0.061655    47894400
# ...                ...         ...         ...         ...         ...
# 2022-05-24  257.890015  261.329987  253.500000  259.619995    29043900
# 2022-05-25  258.140015  264.579987  257.130005  262.519989    28547900
# 2022-05-26  262.269989  267.109985  261.429993  265.899994    25002100
# 2022-05-27  268.480011  273.339996  267.559998  273.239990    26889500
# 2022-05-31  272.529999  274.769989  268.929993  271.869995    37815100
#
#             Dividends  Stock Splits
# Date
# 1986-03-13        0.0           0.0
# ...

# %%
today = hist[len(hist) - 1:]
today

# %%
today = today.assign(Name = msft.info['shortName'])

# %%
today

# %%
today_json = today.to_json(orient='records')
print(type(today_json))
parsed = json.loads(today_json)
parsed[0].update({'test':123})
#json.dumps(parsed)
print(parsed)

# %%
parsed[0].items()

# %%
# show actions (dividends, splits)
msft.actions

# %%
# show dividends
msft.dividends

# %%
# show splits
msft.splits

# %%
# show financials
msft.financials
msft.quarterly_financials

# %%
# show major holders
msft.major_holders

# %%
# show institutional holders
msft.institutional_holders

# %%
# show balance sheet
msft.balance_sheet
msft.quarterly_balance_sheet

# %%
# show cashflow
msft.cashflow
msft.quarterly_cashflow

# %%
# show earnings
msft.earnings
msft.quarterly_earnings

# %%
# show sustainability
msft.sustainability

# %%
# show analysts recommendations
msft.recommendations

# %%
# show next event (earnings, etc)
msft.calendar

# %%
msft.option_chain('2022-06-03')
# Out:
# Options(calls=         contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0   MSFT220603C00170000 2022-05-27 13:59:45+00:00   170.0     100.43  100.00
# 1   MSFT220603C00175000 2022-05-31 18:55:17+00:00   175.0      96.39   95.90
# 2   MSFT220603C00180000 2022-05-18 16:29:59+00:00   180.0      77.35   89.55
# 3   MSFT220603C00185000 2022-05-19 14:32:03+00:00   185.0      69.81   84.80
# 4   MSFT220603C00200000 2022-05-27 14:05:49+00:00   200.0      70.67   69.70
# 5   MSFT220603C00205000 2022-05-27 17:36:47+00:00   205.0      66.18   65.75
# 6   MSFT220603C00210000 2022-05-26 17:58:22+00:00   210.0      56.39   59.75
# 7   MSFT220603C00215000 2022-05-20 16:35:49+00:00   215.0      35.86   55.00
# 8   MSFT220603C00220000 2022-05-27 16:37:26+00:00   220.0      51.82   50.00
# 9   MSFT220603C00225000 2022-05-23 17:18:34+00:00   225.0      35.00   45.20
# 10  MSFT220603C00227500 2022-05-25 15:28:24+00:00   227.5      32.40   42.30
# ...
